# %%
# !python -V
# Out:
# Python 3.10.9

# %%
import pandas as pd

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
import mlflow


mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='/home/mlops/mlops-zoomcamp/02-experiment-tracking/mlruns/1', creation_time=1685287549902, experiment_id='1', last_update_time=1685287549902, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
def read_dataframe(filename):

    df = pd.read_parquet(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('./data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 7.758715204122913

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "cristian")

    mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
    mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")

    alpha = 0.01
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [11:08:05] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:9.77343
# [1]	validation-rmse:7.30643
# [2]	validation-rmse:6.82992
# [3]	validation-rmse:6.71679
# [4]	validation-rmse:6.67583
# [5]	validation-rmse:6.65698
# [6]	validation-rmse:6.65082
# [7]	validation-rmse:6.64376
# [8]	validation-rmse:6.64046
# [9]	validation-rmse:6.63863
# [10]	validation-rmse:6.63304
# [11]	validation-rmse:6.63118
# [12]	validation-rmse:6.62902
# [13]	validation-rmse:6.62786
# [14]	validation-rmse:6.62578
# [15]	validation-rmse:6.62579
# [16]	validation-rmse:6.62640
# [17]	validation-rmse:6.62659
# [18]	validation-rmse:6.62570
# [19]	validation-rmse:6.62501
# [20]	validation-rmse:6.62382
# [21]	validation-rmse:6.62256
# [22]	validation-rmse:6.62243
# [23]	validation-rmse:6.62140
# [24]	validation-rmse:6.62042
# [25]	validation-rmse:6.61887
# [26]	validation-rmse:6.61909
# [27]	validation-rmse:6.61937
# [28]	validation-rmse:6.62007
# [29]	validation-rmse:6.61916
# [30]	validation-rmse:6.61856
# [31]	validation-rmse:6.61976
# [32]	validation-rmse:6.62086
# [33]	validation-rmse:6.62142
# [34]	validation-rmse:6.62083
# [35]	validation-rmse:6.62101
# [36]	validation-rmse:6.62106
# [37]	validation-rmse:6.62116
# [38]	validation-rmse:6.62103
# [39]	validation-rmse:6.62124
# [40]	validation-rmse:6.62196
# [41]	validation-rmse:6.62163
# [42]	validation-rmse:6.62120
# [43]	validation-rmse:6.62045
# [44]	validation-rmse:6.62107
# [45]	validation-rmse:6.62097
# [46]	validation-rmse:6.62100
# [47]	validation-rmse:6.62364
# [48]	validation-rmse:6.62417
# [49]	validation-rmse:6.62354
# [50]	validation-rmse:6.62319
# [51]	validation-rmse:6.62311
# [52]	validation-rmse:6.62329
# [53]	validation-rmse:6.62299
# [54]	validation-rmse:6.62294
# [55]	validation-rmse:6.62381
# [56]	validation-rmse:6.62353
# [57]	validation-rmse:6.62285
# [58]	validation-rmse:6.62344
# [59]	validation-rmse:6.62364
# [60]	validation-rmse:6.62284
# [61]	validation-rmse:6.62257
# [62]	validation-rmse:6.62249
# [63]	validation-rmse:6.62262
# [64]	validation-rmse:6.62231
# [65]	validation-rmse:6.62226
# [66]	validation-rmse:6.62265
# [67]	validation-rmse:6.62336
# [68]	validation-rmse:6.62458
# [69]	validation-rmse:6.62506
# [70]	validation-rmse:6.62481
# [71]	validation-rmse:6.62487
# [72]	validation-rmse:6.62451
# [73]	validation-rmse:6.62403
# [74]	validation-rmse:6.62423
# [75]	validation-rmse:6.62421
# [76]	validation-rmse:6.62426
# [77]	validation-rmse:6.62413
# [78]	validation-rmse:6.62420
# [79]	validation-rmse:6.62478
# [11:08:25] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:9.91388
# [1]	validation-rmse:7.27587
# [2]	validation-rmse:6.71162
# [3]	validation-rmse:6.57167
# [4]	validation-rmse:6.51905
# [5]	validation-rmse:6.50076
# [6]	validation-rmse:6.48719
# [7]	validation-rmse:6.48026
# [8]	validation-rmse:6.47216
# [9]	validation-rmse:6.46501
# [10]	validation-rmse:6.46193
# [11]	validation-rmse:6.45596
# [12]	validation-rmse:6.45054
# [13]	validation-rmse:6.44578
# [14]	validation-rmse:6.44308
# [15]	validation-rmse:6.44055
# [16]	validation-rmse:6.43628
# [17]	validation-rmse:6.43125
# [18]	validation-rmse:6.42578
# [19]	validation-rmse:6.42458
# [20]	validation-rmse:6.42236
# [21]	validation-rmse:6.42008
# [22]	validation-rmse:6.41778
# [23]	validation-rmse:6.41512
# [24]	validation-rmse:6.41138
# [25]	validation-rmse:6.41030
# [26]	validation-rmse:6.41183
# [27]	validation-rmse:6.41109
# [28]	validation-rmse:6.40939
# [29]	validation-rmse:6.40832
# [30]	validation-rmse:6.40521
# [31]	validation-rmse:6.40454
# [32]	validation-rmse:6.40372
# [33]	validation-rmse:6.40235
# [34]	validation-rmse:6.39941
# [35]	validation-rmse:6.39756
# [36]	validation-rmse:6.39740
# [37]	validation-rmse:6.39718
# [38]	validation-rmse:6.39744
# [39]	validation-rmse:6.39728
# [40]	validation-rmse:6.39746
# [41]	validation-rmse:6.39552
# [42]	validation-rmse:6.39622
# [43]	validation-rmse:6.39630
# [44]	validation-rmse:6.39661
# [45]	validation-rmse:6.39498
# [46]	validation-rmse:6.39488
# [47]	validation-rmse:6.39427
# [48]	validation-rmse:6.39420
# [49]	validation-rmse:6.40376
# [50]	validation-rmse:6.40639
# [51]	validation-rmse:6.40593
# [52]	validation-rmse:6.40550
# [53]	validation-rmse:6.40466
# [54]	validation-rmse:6.40464
# [55]	validation-rmse:6.40605
# [56]	validation-rmse:6.40056
# [57]	validation-rmse:6.40147
# [58]	validation-rmse:6.40056
# [59]	validation-rmse:6.40052
# [60]	validation-rmse:6.40077
# [61]	validation-rmse:6.40293
# [62]	validation-rmse:6.40116
# [63]	validation-rmse:6.40009
# [64]	validation-rmse:6.40281
# [65]	validation-rmse:6.40382
# [66]	validation-rmse:6.40383
# [67]	validation-rmse:6.40307
# [68]	validation-rmse:6.40446
# [69]	validation-rmse:6.40519
# [70]	validation-rmse:6.40551
# [71]	validation-rmse:6.40734
# [72]	validation-rmse:6.40769
# [73]	validation-rmse:6.40973
# [74]	validation-rmse:6.40972
# [75]	validation-rmse:6.40869
# [76]	validation-rmse:6.41003
# [77]	validation-rmse:6.40962
# [78]	validation-rmse:6.41305
# [79]	validation-rmse:6.41425
# [80]	validation-rmse:6.41444
# [81]	validation-rmse:6.41509
# [82]	validation-rmse:6.41569
# [83]	validation-rmse:6.41492
# [84]	validation-rmse:6.41646
# [85]	validation-rmse:6.41720
# [86]	validation-rmse:6.41669
# [87]	validation-rmse:6.41676
# [88]	validation-rmse:6.41491
# [89]	validation-rmse:6.41760
# [90]	validation-rmse:6.41770
# [91]	validation-rmse:6.41781
# [92]	validation-rmse:6.41833
# [93]	validation-rmse:6.41826
# [94]	validation-rmse:6.41888
# [95]	validation-rmse:6.41896
# [96]	validation-rmse:6.41856
# [97]	validation-rmse:6.41820
# [98]	validation-rmse:6.42046
# [11:08:42] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:19.70921
# [1]	validation-rmse:18.36074
# [2]	validation-rmse:17.13609
# [3]	validation-rmse:16.02710
# [4]	validation-rmse:15.02223
# [5]	validation-rmse:14.11259
# [6]	validation-rmse:13.29394
# [7]	validation-rmse:12.55647
# [8]	validation-rmse:11.89209
# [9]	validation-rmse:11.29691
# [10]	validation-rmse:10.76351
# [11]	validation-rmse:10.28751
# [12]	validation-rmse:9.86235
# [13]	validation-rmse:9.48421
# [14]	validation-rmse:9.14681
# [15]	validation-rmse:8.84877
# [16]	validation-rmse:8.58250
# [17]	validation-rmse:8.34744
# [18]	validation-rmse:8.14159
# [19]	validation-rmse:7.95695
# [20]	validation-rmse:7.79443
# [21]	validation-rmse:7.65110
# [22]	validation-rmse:7.52481
# [23]	validation-rmse:7.41307
# [24]	validation-rmse:7.31407
# [25]	validation-rmse:7.22811
# [26]	validation-rmse:7.15174
# [27]	validation-rmse:7.08394
# [28]	validation-rmse:7.02433
# [29]	validation-rmse:6.97060
# [30]	validation-rmse:6.92340
# [31]	validation-rmse:6.88084
# [32]	validation-rmse:6.84303
# [33]	validation-rmse:6.80957
# [34]	validation-rmse:6.77921
# [35]	validation-rmse:6.75195
# [36]	validation-rmse:6.72790
# [37]	validation-rmse:6.70622
# [38]	validation-rmse:6.68732
# [39]	validation-rmse:6.66953
# [40]	validation-rmse:6.65295
# [41]	validation-rmse:6.63774
# [42]	validation-rmse:6.62424
# [43]	validation-rmse:6.61163
# [44]	validation-rmse:6.59988
# [45]	validation-rmse:6.58916
# [46]	validation-rmse:6.58017
# [47]	validation-rmse:6.57107
# [48]	validation-rmse:6.56278
# [49]	validation-rmse:6.55546
# [50]	validation-rmse:6.54850
# [51]	validation-rmse:6.54223
# [52]	validation-rmse:6.53718
# [53]	validation-rmse:6.53237
# [54]	validation-rmse:6.52744
# [55]	validation-rmse:6.52308
# [56]	validation-rmse:6.51904
# [57]	validation-rmse:6.51554
# [58]	validation-rmse:6.51217
# [59]	validation-rmse:6.50892
# [60]	validation-rmse:6.50592
# [61]	validation-rmse:6.50312
# [62]	validation-rmse:6.50078
# [63]	validation-rmse:6.49904
# [64]	validation-rmse:6.49696
# [65]	validation-rmse:6.49479
# [66]	validation-rmse:6.49324
# [67]	validation-rmse:6.49162
# [68]	validation-rmse:6.48985
# [69]	validation-rmse:6.48805
# [70]	validation-rmse:6.48699
# [71]	validation-rmse:6.48515
# [72]	validation-rmse:6.48350
# [73]	validation-rmse:6.48203
# [74]	validation-rmse:6.48075
# [75]	validation-rmse:6.47960
# [76]	validation-rmse:6.47829
# [77]	validation-rmse:6.47708
# [78]	validation-rmse:6.47580
# [79]	validation-rmse:6.47460
# [80]	validation-rmse:6.47369
# [81]	validation-rmse:6.47291
# [82]	validation-rmse:6.47160
# [83]	validation-rmse:6.47063
# [84]	validation-rmse:6.46969
# [85]	validation-rmse:6.46865
# [86]	validation-rmse:6.46778
# [87]	validation-rmse:6.46704
# [88]	validation-rmse:6.46627
# [89]	validation-rmse:6.46561
# [90]	validation-rmse:6.46486
# [91]	validation-rmse:6.46424
# [92]	validation-rmse:6.46330
# [93]	validation-rmse:6.46272
# [94]	validation-rmse:6.46211
# [95]	validation-rmse:6.46179
# [96]	validation-rmse:6.46097
# [97]	validation-rmse:6.46035
# [98]	validation-rmse:6.45956
# [99]	validation-rmse:6.45881
# [100]	validation-rmse:6.45816
# [101]	validation-rmse:6.45757
# [102]	validation-rmse:6.45674
# [103]	validation-rmse:6.45620
# [104]	validation-rmse:6.45564
# [105]	validation-rmse:6.45533
# [106]	validation-rmse:6.45463
# [107]	validation-rmse:6.45422
# [108]	validation-rmse:6.45372
# [109]	validation-rmse:6.45291
# [110]	validation-rmse:6.45218
# [111]	validation-rmse:6.45185
# [112]	validation-rmse:6.45126
# [113]	validation-rmse:6.45097
# [114]	validation-rmse:6.45028
# [115]	validation-rmse:6.44977
# [116]	validation-rmse:6.44923
# [117]	validation-rmse:6.44879
# [118]	validation-rmse:6.44828
# [119]	validation-rmse:6.44783
# [120]	validation-rmse:6.44721
# [121]	validation-rmse:6.44672
# [122]	validation-rmse:6.44629
# [123]	validation-rmse:6.44597
# [124]	validation-rmse:6.44555
# [125]	validation-rmse:6.44521
# [126]	validation-rmse:6.44456
# [127]	validation-rmse:6.44423
# [128]	validation-rmse:6.44401
# [129]	validation-rmse:6.44328
# [130]	validation-rmse:6.44296
# [131]	validation-rmse:6.44277
# [132]	validation-rmse:6.44222
# [133]	validation-rmse:6.44193
# [134]	validation-rmse:6.44146
# [135]	validation-rmse:6.44099
# [136]	validation-rmse:6.44065
# [137]	validation-rmse:6.44016
# [138]	validation-rmse:6.43978
# [139]	validation-rmse:6.43944
# [140]	validation-rmse:6.43893
# [141]	validation-rmse:6.43865
# [142]	validation-rmse:6.43831
# [143]	validation-rmse:6.43795
# [144]	validation-rmse:6.43753
# [145]	validation-rmse:6.43733
# [146]	validation-rmse:6.43701
# [147]	validation-rmse:6.43682
# [148]	validation-rmse:6.43646
# [149]	validation-rmse:6.43596
# [150]	validation-rmse:6.43573
# [151]	validation-rmse:6.43520
# [152]	validation-rmse:6.43476
# [153]	validation-rmse:6.43463
# [154]	validation-rmse:6.43444
# [155]	validation-rmse:6.43414
# [156]	validation-rmse:6.43396
# [157]	validation-rmse:6.43354
# [158]	validation-rmse:6.43317
# [159]	validation-rmse:6.43281
# [160]	validation-rmse:6.43229
# [161]	validation-rmse:6.43202
# [162]	validation-rmse:6.43172
# [163]	validation-rmse:6.43143
# [164]	validation-rmse:6.43092
# [165]	validation-rmse:6.43075
# [166]	validation-rmse:6.43058
# [167]	validation-rmse:6.43024
# [168]	validation-rmse:6.42998
# [169]	validation-rmse:6.42969
# [170]	validation-rmse:6.42938
# [171]	validation-rmse:6.42923
# [172]	validation-rmse:6.42882
# [173]	validation-rmse:6.42857
# [174]	validation-rmse:6.42822
# [175]	validation-rmse:6.42803
# [176]	validation-rmse:6.42787
# [177]	validation-rmse:6.42771
# [178]	validation-rmse:6.42742
# [179]	validation-rmse:6.42716
# [180]	validation-rmse:6.42706
# [181]	validation-rmse:6.42666
# [182]	validation-rmse:6.42670
# [183]	validation-rmse:6.42641
# [184]	validation-rmse:6.42619
# [185]	validation-rmse:6.42600
# [186]	validation-rmse:6.42562
# [187]	validation-rmse:6.42542
# [188]	validation-rmse:6.42500
# [189]	validation-rmse:6.42465
# [190]	validation-rmse:6.42444
# [191]	validation-rmse:6.42410
# [192]	validation-rmse:6.42383
# [193]	validation-rmse:6.42371
# [194]	validation-rmse:6.42335
# [195]	validation-rmse:6.42288
# [196]	validation-rmse:6.42260
# [197]	validation-rmse:6.42231
# [198]	validation-rmse:6.42217
# [199]	validation-rmse:6.42194
# [200]	validation-rmse:6.42173
# [201]	validation-rmse:6.42153
# [202]	validation-rmse:6.42139
# [203]	validation-rmse:6.42100
# [204]	validation-rmse:6.42078
# [205]	validation-rmse:6.42057
# [206]	validation-rmse:6.42039
# [207]	validation-rmse:6.42020
# [208]	validation-rmse:6.41995
# [209]	validation-rmse:6.41973
# [210]	validation-rmse:6.41961
# [211]	validation-rmse:6.41940
# [212]	validation-rmse:6.41924
# [213]	validation-rmse:6.41895
# [214]	validation-rmse:6.41885
# [215]	validation-rmse:6.41871
# [216]	validation-rmse:6.41846
# [217]	validation-rmse:6.41833
# [218]	validation-rmse:6.41802
# [219]	validation-rmse:6.41781
# [220]	validation-rmse:6.41751
# [221]	validation-rmse:6.41727
# [222]	validation-rmse:6.41709
# [223]	validation-rmse:6.41682
# [224]	validation-rmse:6.41667
# [225]	validation-rmse:6.41650
# [226]	validation-rmse:6.41630
# [227]	validation-rmse:6.41599
# [228]	validation-rmse:6.41583
# [229]	validation-rmse:6.41549
# [230]	validation-rmse:6.41531
# [231]	validation-rmse:6.41518
# [232]	validation-rmse:6.41486
# [233]	validation-rmse:6.41474
# [234]	validation-rmse:6.41454
# [235]	validation-rmse:6.41438
# [236]	validation-rmse:6.41439
# [237]	validation-rmse:6.41417
# [238]	validation-rmse:6.41405
# [239]	validation-rmse:6.41372
# [240]	validation-rmse:6.41361
# [241]	validation-rmse:6.41355
# [242]	validation-rmse:6.41338
# [243]	validation-rmse:6.41303
# [244]	validation-rmse:6.41302
# [245]	validation-rmse:6.41287
# [246]	validation-rmse:6.41266
# [247]	validation-rmse:6.41252
# [248]	validation-rmse:6.41236
# [249]	validation-rmse:6.41218
# [250]	validation-rmse:6.41205
# [251]	validation-rmse:6.41191
# [252]	validation-rmse:6.41173
# [253]	validation-rmse:6.41170
# [254]	validation-rmse:6.41153
# [255]	validation-rmse:6.41126
# [256]	validation-rmse:6.41102
# [257]	validation-rmse:6.41084
# [258]	validation-rmse:6.41075
# [259]	validation-rmse:6.41046
# [260]	validation-rmse:6.41028
# [261]	validation-rmse:6.41000
# [262]	validation-rmse:6.40984
# [263]	validation-rmse:6.40967
# [264]	validation-rmse:6.40961
# [265]	validation-rmse:6.40933
# [266]	validation-rmse:6.40905
# [267]	validation-rmse:6.40878
# [268]	validation-rmse:6.40866
# [269]	validation-rmse:6.40836
# [270]	validation-rmse:6.40825
# [271]	validation-rmse:6.40805
# [272]	validation-rmse:6.40800
# [273]	validation-rmse:6.40795
# [274]	validation-rmse:6.40788
# [275]	validation-rmse:6.40768
# [276]	validation-rmse:6.40762
# [277]	validation-rmse:6.40746
# [278]	validation-rmse:6.40755
# [279]	validation-rmse:6.40742
# [280]	validation-rmse:6.40734
# [281]	validation-rmse:6.40710
# [282]	validation-rmse:6.40690
# [283]	validation-rmse:6.40672
# [284]	validation-rmse:6.40663
# [285]	validation-rmse:6.40635
# [286]	validation-rmse:6.40621
# [287]	validation-rmse:6.40591
# [288]	validation-rmse:6.40580
# [289]	validation-rmse:6.40578
# [290]	validation-rmse:6.40562
# [291]	validation-rmse:6.40558
# [292]	validation-rmse:6.40559
# [293]	validation-rmse:6.40544
# [294]	validation-rmse:6.40535
# [295]	validation-rmse:6.40516
# [296]	validation-rmse:6.40509
# [297]	validation-rmse:6.40499
# [298]	validation-rmse:6.40492
# [299]	validation-rmse:6.40466
# [300]	validation-rmse:6.40464
# [301]	validation-rmse:6.40445
# [302]	validation-rmse:6.40421
# [303]	validation-rmse:6.40413
# [304]	validation-rmse:6.40403
# [305]	validation-rmse:6.40383
# [306]	validation-rmse:6.40369
# [307]	validation-rmse:6.40366
# [308]	validation-rmse:6.40345
# [309]	validation-rmse:6.40298
# [310]	validation-rmse:6.40296
# [311]	validation-rmse:6.40281
# [312]	validation-rmse:6.40283
# [313]	validation-rmse:6.40267
# [314]	validation-rmse:6.40266
# [315]	validation-rmse:6.40252
# [316]	validation-rmse:6.40246
# [317]	validation-rmse:6.40248
# [318]	validation-rmse:6.40226
# [319]	validation-rmse:6.40226
# [320]	validation-rmse:6.40217
# [321]	validation-rmse:6.40199
# [322]	validation-rmse:6.40195
# [323]	validation-rmse:6.40190
# [324]	validation-rmse:6.40180
# [325]	validation-rmse:6.40150
# [326]	validation-rmse:6.40141
# [327]	validation-rmse:6.40133
# [328]	validation-rmse:6.40101
# [329]	validation-rmse:6.40090
# [330]	validation-rmse:6.40067
# [331]	validation-rmse:6.40059
# [332]	validation-rmse:6.40038
# [333]	validation-rmse:6.40020
# [334]	validation-rmse:6.40010
# [335]	validation-rmse:6.40010
# [336]	validation-rmse:6.40000
# [337]	validation-rmse:6.39995
# [338]	validation-rmse:6.40001
# [339]	validation-rmse:6.39980
# [340]	validation-rmse:6.39967
# [341]	validation-rmse:6.39954
# [342]	validation-rmse:6.39930
# [343]	validation-rmse:6.39936
# [344]	validation-rmse:6.39924
# [345]	validation-rmse:6.39915
# [346]	validation-rmse:6.39898
# [347]	validation-rmse:6.39893
# [348]	validation-rmse:6.39882
# [349]	validation-rmse:6.39865
# [350]	validation-rmse:6.39858
# [351]	validation-rmse:6.39835
# [352]	validation-rmse:6.39823
# [353]	validation-rmse:6.39830
# [354]	validation-rmse:6.39844
# [355]	validation-rmse:6.39838
# [356]	validation-rmse:6.39866
# [357]	validation-rmse:6.39855
# [358]	validation-rmse:6.39851
# [359]	validation-rmse:6.39845
# [360]	validation-rmse:6.39836
# [361]	validation-rmse:6.39837
# [362]	validation-rmse:6.39825
# [363]	validation-rmse:6.39818
# [364]	validation-rmse:6.39806
# [365]	validation-rmse:6.39777
# [366]	validation-rmse:6.39778
# [367]	validation-rmse:6.39763
# [368]	validation-rmse:6.39755
# [369]	validation-rmse:6.39734
# [370]	validation-rmse:6.39714
# [371]	validation-rmse:6.39687
# [372]	validation-rmse:6.39693
# [373]	validation-rmse:6.39685
# [374]	validation-rmse:6.39673
# [375]	validation-rmse:6.39671
# [376]	validation-rmse:6.39651
# [377]	validation-rmse:6.39653
# [378]	validation-rmse:6.39657
# [379]	validation-rmse:6.39670
# [380]	validation-rmse:6.39658
# [381]	validation-rmse:6.39646
# [382]	validation-rmse:6.39637
# [383]	validation-rmse:6.39633
# [384]	validation-rmse:6.39626
# [385]	validation-rmse:6.39612
# [386]	validation-rmse:6.39600
# [387]	validation-rmse:6.39592
# [388]	validation-rmse:6.39575
# [389]	validation-rmse:6.39583
# [390]	validation-rmse:6.39569
# [391]	validation-rmse:6.39564
# [392]	validation-rmse:6.39555
# [393]	validation-rmse:6.39523
# [394]	validation-rmse:6.39511
# [395]	validation-rmse:6.39496
# [396]	validation-rmse:6.39492
# [397]	validation-rmse:6.39482
# [398]	validation-rmse:6.39474
# [399]	validation-rmse:6.39504
# [400]	validation-rmse:6.39492
# [401]	validation-rmse:6.39475
# [402]	validation-rmse:6.39476
# [403]	validation-rmse:6.39473
# [404]	validation-rmse:6.39483
# [405]	validation-rmse:6.39463
# [406]	validation-rmse:6.39463
# [407]	validation-rmse:6.39475
# [408]	validation-rmse:6.39472
# [409]	validation-rmse:6.39462
# [410]	validation-rmse:6.39452
# [411]	validation-rmse:6.39431
# [412]	validation-rmse:6.39419
# [413]	validation-rmse:6.39412
# [414]	validation-rmse:6.39396
# [415]	validation-rmse:6.39388
# [416]	validation-rmse:6.39376
# [417]	validation-rmse:6.39363
# [418]	validation-rmse:6.39349
# [419]	validation-rmse:6.39337
# [420]	validation-rmse:6.39361
# [421]	validation-rmse:6.39364
# [422]	validation-rmse:6.39375
# [423]	validation-rmse:6.39381
# [424]	validation-rmse:6.39372
# [425]	validation-rmse:6.39364
# [426]	validation-rmse:6.39356
# [427]	validation-rmse:6.39348
# [428]	validation-rmse:6.39342
# [429]	validation-rmse:6.39336
# [430]	validation-rmse:6.39333
# [431]	validation-rmse:6.39329
# [432]	validation-rmse:6.39322
# [433]	validation-rmse:6.39318
# [434]	validation-rmse:6.39316
# [435]	validation-rmse:6.39300
# [436]	validation-rmse:6.39299
# [437]	validation-rmse:6.39281
# [438]	validation-rmse:6.39276
# [439]	validation-rmse:6.39247
# ...
# [418]	validation-rmse:6.67587
# [419]	validation-rmse:6.67581
# [420]	validation-rmse:6.67587
# [421]	validation-rmse:6.67592
# [422]	validation-rmse:6.67587
# [423]	validation-rmse:6.67588
# [424]	validation-rmse:6.67582
# [425]	validation-rmse:6.67581
# [426]	validation-rmse:6.67581
# [427]	validation-rmse:6.67572
# [428]	validation-rmse:6.67570
# [429]	validation-rmse:6.67565
# [430]	validation-rmse:6.67569
# [431]	validation-rmse:6.67561
# [432]	validation-rmse:6.67565
# [433]	validation-rmse:6.67559
# [434]	validation-rmse:6.67558
# [435]	validation-rmse:6.67554
# [436]	validation-rmse:6.67556
# [437]	validation-rmse:6.67557
# [438]	validation-rmse:6.67551
# [439]	validation-rmse:6.67548
# [440]	validation-rmse:6.67550
# [441]	validation-rmse:6.67554
# [442]	validation-rmse:6.67555
# [443]	validation-rmse:6.67551
# [444]	validation-rmse:6.67550
# [445]	validation-rmse:6.67550
# [446]	validation-rmse:6.67544
# [447]	validation-rmse:6.67541
# [448]	validation-rmse:6.67537
# [449]	validation-rmse:6.67538
# [450]	validation-rmse:6.67533
# [451]	validation-rmse:6.67527
# [452]	validation-rmse:6.67534
# [453]	validation-rmse:6.67537
# [454]	validation-rmse:6.67535
# [455]	validation-rmse:6.67527
# [456]	validation-rmse:6.67524
# [457]	validation-rmse:6.67526
# [458]	validation-rmse:6.67523
# [459]	validation-rmse:6.67523
# [460]	validation-rmse:6.67520
# [461]	validation-rmse:6.67521
# [462]	validation-rmse:6.67517
# [463]	validation-rmse:6.67513
# [464]	validation-rmse:6.67514
# [465]	validation-rmse:6.67512
# [466]	validation-rmse:6.67515
# [467]	validation-rmse:6.67511
# [468]	validation-rmse:6.67510
# [469]	validation-rmse:6.67504
# [470]	validation-rmse:6.67501
# [471]	validation-rmse:6.67502
# [472]	validation-rmse:6.67494
# [473]	validation-rmse:6.67499
# [474]	validation-rmse:6.67494
# [475]	validation-rmse:6.67491
# [476]	validation-rmse:6.67491
# [477]	validation-rmse:6.67492
# [478]	validation-rmse:6.67493
# [479]	validation-rmse:6.67489
# [480]	validation-rmse:6.67490
# [481]	validation-rmse:6.67487
# [482]	validation-rmse:6.67485
# [483]	validation-rmse:6.67485
# [484]	validation-rmse:6.67487
# [485]	validation-rmse:6.67486
# [486]	validation-rmse:6.67483
# [487]	validation-rmse:6.67480
# [488]	validation-rmse:6.67479
# [489]	validation-rmse:6.67477
# [490]	validation-rmse:6.67477
# [491]	validation-rmse:6.67475
# [492]	validation-rmse:6.67469
# [493]	validation-rmse:6.67469
# [494]	validation-rmse:6.67464
# [495]	validation-rmse:6.67461
# [496]	validation-rmse:6.67462
# [497]	validation-rmse:6.67457
# [498]	validation-rmse:6.67453
# [499]	validation-rmse:6.67456
# [500]	validation-rmse:6.67449
# [501]	validation-rmse:6.67448
# [502]	validation-rmse:6.67446
# [503]	validation-rmse:6.67442
# [504]	validation-rmse:6.67446
# [505]	validation-rmse:6.67445
# [506]	validation-rmse:6.67448
# [507]	validation-rmse:6.67441
# [508]	validation-rmse:6.67439
# [509]	validation-rmse:6.67436
# [510]	validation-rmse:6.67434
# [511]	validation-rmse:6.67440
# [512]	validation-rmse:6.67433
# [513]	validation-rmse:6.67427
# [514]	validation-rmse:6.67430
# [515]	validation-rmse:6.67427
# [516]	validation-rmse:6.67429
# [517]	validation-rmse:6.67429
# [518]	validation-rmse:6.67433
# [519]	validation-rmse:6.67426
# [520]	validation-rmse:6.67422
# [521]	validation-rmse:6.67421
# [522]	validation-rmse:6.67419
# [523]	validation-rmse:6.67421
# [524]	validation-rmse:6.67422
# [525]	validation-rmse:6.67422
# [526]	validation-rmse:6.67418
# [527]	validation-rmse:6.67415
# [528]	validation-rmse:6.67419
# [529]	validation-rmse:6.67415
#  30%|███       | 15/50 [20:16<47:17, 81.07s/trial, best loss: 6.287340220661962]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 11
#       1 search_space = {
#       2     'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
#       3     'learning_rate': hp.loguniform('learning_rate', -3, 0),
#    (...)
#       8     'seed': 42
#       9 }
# ---> 11 best_result = fmin(
#      12     fn=objective,
#      13     space=search_space,
#      14     algo=tpe.suggest,
#      15     max_evals=50,
#      16     trials=Trials()
#      17 )
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.10/site-packages/hyperopt/fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.10/site-packages/hyperopt/base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.10/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.10/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.10/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.10/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.10/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[27], line 5, in objective(params)
#       3 mlflow.set_tag("model", "xgboost")
#       4 mlflow.log_params(params)
# ----> 5 booster = xgb.train(
#       6     params=params,
#       7     dtrain=train,
#       8     num_boost_round=1000,
#       9     evals=[(valid, 'validation')],
#      10     early_stopping_rounds=50
#      11 )
#      12 y_pred = booster.predict(valid)
#      13 rmse = mean_squared_error(y_val, y_pred, squared=False)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.10/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.10/site-packages/xgboost/training.py:185, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     183 if cb_container.before_iteration(bst, i, dtrain, evals):
#     184     break
# --> 185 bst.update(dtrain, i, obj)
#     186 if cb_container.after_iteration(bst, i, dtrain, evals):
#     187     break
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.10/site-packages/xgboost/core.py:1918, in Booster.update(self, dtrain, iteration, fobj)
#    1915 self._validate_dmatrix_features(dtrain)
#    1917 if fobj is None:
# -> 1918     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1919                                             ctypes.c_int(iteration),
#    1920                                             dtrain.handle))
#    1921 else:
#    1922     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:linear',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

mlflow.xgboost.autolog()

booster = xgb.train(
    params=best_params,
    dtrain=train,
    num_boost_round=50,
    evals=[(valid, 'validation')],
    early_stopping_rounds=50
)
# Out:
# 2023/05/28 11:40:37 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'baa0c4fa9ddb4f98a59f398d06434028', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# [11:40:37] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:19.48425
# [1]	validation-rmse:17.95635
# [2]	validation-rmse:16.59103
# [3]	validation-rmse:15.37412
# [4]	validation-rmse:14.29029
# [5]	validation-rmse:13.32807
# [6]	validation-rmse:12.47571
# [7]	validation-rmse:11.72138
# [8]	validation-rmse:11.05825
# [9]	validation-rmse:10.47535
# [10]	validation-rmse:9.96449
# [11]	validation-rmse:9.51756
# [12]	validation-rmse:9.12641
# [13]	validation-rmse:8.78569
# [14]	validation-rmse:8.49089
# [15]	validation-rmse:8.23445
# [16]	validation-rmse:8.01207
# [17]	validation-rmse:7.81886
# [18]	validation-rmse:7.65169
# [19]	validation-rmse:7.50672
# [20]	validation-rmse:7.38153
# [21]	validation-rmse:7.27299
# [22]	validation-rmse:7.17863
# [23]	validation-rmse:7.09718
# [24]	validation-rmse:7.02603
# [25]	validation-rmse:6.96344
# [26]	validation-rmse:6.90935
# [27]	validation-rmse:6.86285
# [28]	validation-rmse:6.82157
# [29]	validation-rmse:6.78486
# [30]	validation-rmse:6.75283
# [31]	validation-rmse:6.72433
# [32]	validation-rmse:6.69838
# [33]	validation-rmse:6.67599
# [34]	validation-rmse:6.65632
# [35]	validation-rmse:6.63968
# [36]	validation-rmse:6.62456
# [37]	validation-rmse:6.61030
# [38]	validation-rmse:6.59833
# [39]	validation-rmse:6.58671
# [40]	validation-rmse:6.57678
# [41]	validation-rmse:6.56792
# [42]	validation-rmse:6.56024
# [43]	validation-rmse:6.55307
# [44]	validation-rmse:6.54644
# [45]	validation-rmse:6.54087
# [46]	validation-rmse:6.53587
# [47]	validation-rmse:6.53128
# [48]	validation-rmse:6.52719
# [49]	validation-rmse:6.52427
# 2023/05/28 11:40:54 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.

# %%
with mlflow.start_run():
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:linear',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# [14:36:31] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:19.48425
# [1]	validation-rmse:17.95635
# [2]	validation-rmse:16.59103
# [3]	validation-rmse:15.37412
# [4]	validation-rmse:14.29029
# [5]	validation-rmse:13.32807
# [6]	validation-rmse:12.47571
# [7]	validation-rmse:11.72138
# [8]	validation-rmse:11.05825
# [9]	validation-rmse:10.47535
# [10]	validation-rmse:9.96449
# [11]	validation-rmse:9.51756
# [12]	validation-rmse:9.12641
# [13]	validation-rmse:8.78569
# [14]	validation-rmse:8.49089
# [15]	validation-rmse:8.23445
# [16]	validation-rmse:8.01207
# [17]	validation-rmse:7.81886
# [18]	validation-rmse:7.65169
# [19]	validation-rmse:7.50672
# [20]	validation-rmse:7.38153
# [21]	validation-rmse:7.27299
# [22]	validation-rmse:7.17863
# [23]	validation-rmse:7.09718
# [24]	validation-rmse:7.02603
# [25]	validation-rmse:6.96344
# [26]	validation-rmse:6.90935
# [27]	validation-rmse:6.86285
# [28]	validation-rmse:6.82157
# [29]	validation-rmse:6.78486
# [30]	validation-rmse:6.75283
# [31]	validation-rmse:6.72433
# [32]	validation-rmse:6.69838
# [33]	validation-rmse:6.67599
# [34]	validation-rmse:6.65632
# [35]	validation-rmse:6.63968
# [36]	validation-rmse:6.62456
# [37]	validation-rmse:6.61030
# [38]	validation-rmse:6.59833
# [39]	validation-rmse:6.58671
# [40]	validation-rmse:6.57678
# [41]	validation-rmse:6.56792
# [42]	validation-rmse:6.56024
# [43]	validation-rmse:6.55307
# [44]	validation-rmse:6.54644
# [45]	validation-rmse:6.54087
# [46]	validation-rmse:6.53587
# [47]	validation-rmse:6.53128
# [48]	validation-rmse:6.52719
# [49]	validation-rmse:6.52427
# [50]	validation-rmse:6.52098
# [51]	validation-rmse:6.51875
# [52]	validation-rmse:6.51547
# [53]	validation-rmse:6.51333
# [54]	validation-rmse:6.51034
# [55]	validation-rmse:6.50826
# [56]	validation-rmse:6.50668
# [57]	validation-rmse:6.50477
# [58]	validation-rmse:6.50288
# [59]	validation-rmse:6.50114
# [60]	validation-rmse:6.49931
# [61]	validation-rmse:6.49758
# [62]	validation-rmse:6.49577
# [63]	validation-rmse:6.49364
# [64]	validation-rmse:6.49179
# [65]	validation-rmse:6.49031
# [66]	validation-rmse:6.48955
# [67]	validation-rmse:6.48814
# [68]	validation-rmse:6.48684
# [69]	validation-rmse:6.48526
# [70]	validation-rmse:6.48384
# [71]	validation-rmse:6.48249
# [72]	validation-rmse:6.48180
# [73]	validation-rmse:6.48127
# [74]	validation-rmse:6.48053
# [75]	validation-rmse:6.47965
# [76]	validation-rmse:6.47878
# [77]	validation-rmse:6.47808
# [78]	validation-rmse:6.47695
# [79]	validation-rmse:6.47605
# [80]	validation-rmse:6.47528
# [81]	validation-rmse:6.47416
# [82]	validation-rmse:6.47331
# [83]	validation-rmse:6.47237
# [84]	validation-rmse:6.47146
# [85]	validation-rmse:6.47022
# [86]	validation-rmse:6.46934
# [87]	validation-rmse:6.46830
# [88]	validation-rmse:6.46799
# [89]	validation-rmse:6.46740
# [90]	validation-rmse:6.46645
# [91]	validation-rmse:6.46556
# [92]	validation-rmse:6.46451
# [93]	validation-rmse:6.46355
# [94]	validation-rmse:6.46222
# [95]	validation-rmse:6.46134
# [96]	validation-rmse:6.46099
# [97]	validation-rmse:6.46062
# [98]	validation-rmse:6.46009
# [99]	validation-rmse:6.45985
# [100]	validation-rmse:6.45925
# [101]	validation-rmse:6.45879
# [102]	validation-rmse:6.45800
# [103]	validation-rmse:6.45743
# [104]	validation-rmse:6.45704
# [105]	validation-rmse:6.45635
# [106]	validation-rmse:6.45573
# [107]	validation-rmse:6.45514
# [108]	validation-rmse:6.45445
# [109]	validation-rmse:6.45347
# [110]	validation-rmse:6.45290
# [111]	validation-rmse:6.45212
# [112]	validation-rmse:6.45163
# [113]	validation-rmse:6.45093
# [114]	validation-rmse:6.45017
# [115]	validation-rmse:6.44938
# [116]	validation-rmse:6.44860
# [117]	validation-rmse:6.44821
# [118]	validation-rmse:6.44777
# [119]	validation-rmse:6.44728
# [120]	validation-rmse:6.44657
# [121]	validation-rmse:6.44601
# [122]	validation-rmse:6.44529
# [123]	validation-rmse:6.44467
# [124]	validation-rmse:6.44404
# [125]	validation-rmse:6.44343
# [126]	validation-rmse:6.44295
# [127]	validation-rmse:6.44240
# [128]	validation-rmse:6.44131
# [129]	validation-rmse:6.44066
# [130]	validation-rmse:6.44046
# [131]	validation-rmse:6.44021
# [132]	validation-rmse:6.43979
# [133]	validation-rmse:6.43959
# [134]	validation-rmse:6.43907
# [135]	validation-rmse:6.43873
# [136]	validation-rmse:6.43819
# [137]	validation-rmse:6.43754
# [138]	validation-rmse:6.43688
# [139]	validation-rmse:6.43666
# [140]	validation-rmse:6.43625
# [141]	validation-rmse:6.43587
# [142]	validation-rmse:6.43529
# [143]	validation-rmse:6.43475
# [144]	validation-rmse:6.43418
# [145]	validation-rmse:6.43377
# [146]	validation-rmse:6.43293
# [147]	validation-rmse:6.43239
# [148]	validation-rmse:6.43176
# [149]	validation-rmse:6.43148
# [150]	validation-rmse:6.43092
# [151]	validation-rmse:6.43041
# [152]	validation-rmse:6.42996
# [153]	validation-rmse:6.42932
# [154]	validation-rmse:6.42880
# [155]	validation-rmse:6.42823
# [156]	validation-rmse:6.42773
# [157]	validation-rmse:6.42761
# [158]	validation-rmse:6.42725
# [159]	validation-rmse:6.42669
# [160]	validation-rmse:6.42627
# [161]	validation-rmse:6.42591
# [162]	validation-rmse:6.42540
# [163]	validation-rmse:6.42489
# [164]	validation-rmse:6.42425
# [165]	validation-rmse:6.42393
# [166]	validation-rmse:6.42328
# [167]	validation-rmse:6.42269
# [168]	validation-rmse:6.42239
# [169]	validation-rmse:6.42194
# [170]	validation-rmse:6.42133
# [171]	validation-rmse:6.42085
# [172]	validation-rmse:6.42040
# [173]	validation-rmse:6.42020
# [174]	validation-rmse:6.42002
# [175]	validation-rmse:6.41973
# [176]	validation-rmse:6.41935
# [177]	validation-rmse:6.41909
# [178]	validation-rmse:6.41862
# [179]	validation-rmse:6.41843
# [180]	validation-rmse:6.41814
# [181]	validation-rmse:6.41735
# [182]	validation-rmse:6.41708
# [183]	validation-rmse:6.41635
# [184]	validation-rmse:6.41627
# [185]	validation-rmse:6.41602
# [186]	validation-rmse:6.41555
# [187]	validation-rmse:6.41550
# [188]	validation-rmse:6.41493
# [189]	validation-rmse:6.41447
# [190]	validation-rmse:6.41404
# [191]	validation-rmse:6.41373
# [192]	validation-rmse:6.41320
# [193]	validation-rmse:6.41298
# [194]	validation-rmse:6.41244
# [195]	validation-rmse:6.41195
# [196]	validation-rmse:6.41166
# [197]	validation-rmse:6.41113
# [198]	validation-rmse:6.41093
# [199]	validation-rmse:6.41061
# [200]	validation-rmse:6.41026
# [201]	validation-rmse:6.40990
# [202]	validation-rmse:6.40940
# [203]	validation-rmse:6.40898
# [204]	validation-rmse:6.40863
# [205]	validation-rmse:6.40824
# [206]	validation-rmse:6.40782
# [207]	validation-rmse:6.40755
# [208]	validation-rmse:6.40740
# [209]	validation-rmse:6.40724
# [210]	validation-rmse:6.40683
# [211]	validation-rmse:6.40635
# [212]	validation-rmse:6.40611
# [213]	validation-rmse:6.40549
# [214]	validation-rmse:6.40514
# [215]	validation-rmse:6.40505
# [216]	validation-rmse:6.40449
# [217]	validation-rmse:6.40426
# [218]	validation-rmse:6.40389
# [219]	validation-rmse:6.40355
# [220]	validation-rmse:6.40308
# [221]	validation-rmse:6.40265
# [222]	validation-rmse:6.40237
# [223]	validation-rmse:6.40215
# [224]	validation-rmse:6.40170
# [225]	validation-rmse:6.40138
# [226]	validation-rmse:6.40104
# [227]	validation-rmse:6.40049
# [228]	validation-rmse:6.40016
# [229]	validation-rmse:6.40000
# [230]	validation-rmse:6.39987
# [231]	validation-rmse:6.39984
# [232]	validation-rmse:6.39941
# [233]	validation-rmse:6.39937
# [234]	validation-rmse:6.39908
# [235]	validation-rmse:6.39884
# [236]	validation-rmse:6.39855
# [237]	validation-rmse:6.39841
# [238]	validation-rmse:6.39801
# [239]	validation-rmse:6.39775
# [240]	validation-rmse:6.39711
# [241]	validation-rmse:6.39684
# [242]	validation-rmse:6.39660
# [243]	validation-rmse:6.39635
# [244]	validation-rmse:6.39624
# [245]	validation-rmse:6.39600
# [246]	validation-rmse:6.39555
# [247]	validation-rmse:6.39556
# [248]	validation-rmse:6.39523
# [249]	validation-rmse:6.39468
# [250]	validation-rmse:6.39437
# [251]	validation-rmse:6.39432
# [252]	validation-rmse:6.39394
# [253]	validation-rmse:6.39375
# [254]	validation-rmse:6.39326
# [255]	validation-rmse:6.39297
# [256]	validation-rmse:6.39265
# [257]	validation-rmse:6.39239
# [258]	validation-rmse:6.39185
# [259]	validation-rmse:6.39174
# [260]	validation-rmse:6.39146
# [261]	validation-rmse:6.39103
# [262]	validation-rmse:6.39096
# [263]	validation-rmse:6.39070
# [264]	validation-rmse:6.39035
# [265]	validation-rmse:6.39008
# [266]	validation-rmse:6.38964
# [267]	validation-rmse:6.38933
# [268]	validation-rmse:6.38887
# [269]	validation-rmse:6.38880
# [270]	validation-rmse:6.38841
# [271]	validation-rmse:6.38790
# [272]	validation-rmse:6.38785
# [273]	validation-rmse:6.38760
# [274]	validation-rmse:6.38752
# [275]	validation-rmse:6.38711
# [276]	validation-rmse:6.38693
# [277]	validation-rmse:6.38679
# [278]	validation-rmse:6.38631
# [279]	validation-rmse:6.38589
# [280]	validation-rmse:6.38573
# [281]	validation-rmse:6.38517
# [282]	validation-rmse:6.38490
# [283]	validation-rmse:6.38479
# [284]	validation-rmse:6.38458
# [285]	validation-rmse:6.38413
# [286]	validation-rmse:6.38405
# [287]	validation-rmse:6.38383
# [288]	validation-rmse:6.38357
# [289]	validation-rmse:6.38302
# [290]	validation-rmse:6.38281
# [291]	validation-rmse:6.38251
# [292]	validation-rmse:6.38235
# [293]	validation-rmse:6.38202
# [294]	validation-rmse:6.38163
# [295]	validation-rmse:6.38126
# [296]	validation-rmse:6.38063
# [297]	validation-rmse:6.38038
# [298]	validation-rmse:6.37990
# [299]	validation-rmse:6.37973
# [300]	validation-rmse:6.37959
# [301]	validation-rmse:6.37926
# [302]	validation-rmse:6.37923
# [303]	validation-rmse:6.37911
# [304]	validation-rmse:6.37905
# [305]	validation-rmse:6.37882
# [306]	validation-rmse:6.37886
# [307]	validation-rmse:6.37864
# [308]	validation-rmse:6.37830
# [309]	validation-rmse:6.37806
# [310]	validation-rmse:6.37790
# [311]	validation-rmse:6.37783
# [312]	validation-rmse:6.37759
# [313]	validation-rmse:6.37705
# [314]	validation-rmse:6.37633
# [315]	validation-rmse:6.37613
# [316]	validation-rmse:6.37577
# [317]	validation-rmse:6.37557
# [318]	validation-rmse:6.37559
# [319]	validation-rmse:6.37545
# [320]	validation-rmse:6.37546
# [321]	validation-rmse:6.37533
# [322]	validation-rmse:6.37506
# [323]	validation-rmse:6.37498
# [324]	validation-rmse:6.37466
# [325]	validation-rmse:6.37432
# [326]	validation-rmse:6.37409
# [327]	validation-rmse:6.37406
# [328]	validation-rmse:6.37381
# [329]	validation-rmse:6.37349
# [330]	validation-rmse:6.37332
# [331]	validation-rmse:6.37311
# [332]	validation-rmse:6.37278
# [333]	validation-rmse:6.37268
# [334]	validation-rmse:6.37249
# [335]	validation-rmse:6.37187
# [336]	validation-rmse:6.37168
# [337]	validation-rmse:6.37150
# [338]	validation-rmse:6.37124
# [339]	validation-rmse:6.37104
# [340]	validation-rmse:6.37081
# [341]	validation-rmse:6.37070
# [342]	validation-rmse:6.37059
# [343]	validation-rmse:6.37034
# [344]	validation-rmse:6.36989
# [345]	validation-rmse:6.36968
# [346]	validation-rmse:6.36942
# [347]	validation-rmse:6.36900
# [348]	validation-rmse:6.36883
# [349]	validation-rmse:6.36881
# [350]	validation-rmse:6.36878
# [351]	validation-rmse:6.36870
# [352]	validation-rmse:6.36836
# [353]	validation-rmse:6.36819
# [354]	validation-rmse:6.36800
# [355]	validation-rmse:6.36786
# [356]	validation-rmse:6.36741
# [357]	validation-rmse:6.36708
# [358]	validation-rmse:6.36708
# [359]	validation-rmse:6.36690
# [360]	validation-rmse:6.36662
# [361]	validation-rmse:6.36647
# [362]	validation-rmse:6.36609
# [363]	validation-rmse:6.36593
# [364]	validation-rmse:6.36571
# [365]	validation-rmse:6.36554
# [366]	validation-rmse:6.36539
# [367]	validation-rmse:6.36530
# [368]	validation-rmse:6.36509
# [369]	validation-rmse:6.36481
# [370]	validation-rmse:6.36468
# [371]	validation-rmse:6.36446
# [372]	validation-rmse:6.36426
# [373]	validation-rmse:6.36403
# [374]	validation-rmse:6.36392
# [375]	validation-rmse:6.36349
# [376]	validation-rmse:6.36331
# [377]	validation-rmse:6.36320
# [378]	validation-rmse:6.36296
# [379]	validation-rmse:6.36266
# [380]	validation-rmse:6.36229
# [381]	validation-rmse:6.36213
# [382]	validation-rmse:6.36202
# [383]	validation-rmse:6.36187
# [384]	validation-rmse:6.36163
# [385]	validation-rmse:6.36137
# [386]	validation-rmse:6.36123
# [387]	validation-rmse:6.36116
# [388]	validation-rmse:6.36094
# [389]	validation-rmse:6.36091
# [390]	validation-rmse:6.36074
# [391]	validation-rmse:6.36075
# [392]	validation-rmse:6.36060
# [393]	validation-rmse:6.36057
# [394]	validation-rmse:6.36038
# [395]	validation-rmse:6.36006
# [396]	validation-rmse:6.35981
# [397]	validation-rmse:6.35966
# [398]	validation-rmse:6.35950
# [399]	validation-rmse:6.35933
# [400]	validation-rmse:6.35930
# [401]	validation-rmse:6.35892
# [402]	validation-rmse:6.35879
# [403]	validation-rmse:6.35839
# [404]	validation-rmse:6.35820
# [405]	validation-rmse:6.35818
# [406]	validation-rmse:6.35804
# [407]	validation-rmse:6.35806
# [408]	validation-rmse:6.35798
# [409]	validation-rmse:6.35805
# [410]	validation-rmse:6.35781
# [411]	validation-rmse:6.35744
# [412]	validation-rmse:6.35733
# [413]	validation-rmse:6.35725
# [414]	validation-rmse:6.35718
# [415]	validation-rmse:6.35679
# [416]	validation-rmse:6.35661
# [417]	validation-rmse:6.35632
# [418]	validation-rmse:6.35615
# [419]	validation-rmse:6.35585
# [420]	validation-rmse:6.35581
# [421]	validation-rmse:6.35546
# [422]	validation-rmse:6.35500
# [423]	validation-rmse:6.35490
# [424]	validation-rmse:6.35478
# [425]	validation-rmse:6.35434
# [426]	validation-rmse:6.35409
# [427]	validation-rmse:6.35399
# [428]	validation-rmse:6.35401
# [429]	validation-rmse:6.35374
# [430]	validation-rmse:6.35360
# [431]	validation-rmse:6.35346
# [432]	validation-rmse:6.35333
# [433]	validation-rmse:6.35315
# [434]	validation-rmse:6.35309
# [435]	validation-rmse:6.35280
# [436]	validation-rmse:6.35266
# [437]	validation-rmse:6.35244
# [438]	validation-rmse:6.35247
# [439]	validation-rmse:6.35225
# [440]	validation-rmse:6.35215
# [441]	validation-rmse:6.35188
# [442]	validation-rmse:6.35170
# [443]	validation-rmse:6.35154
# [444]	validation-rmse:6.35145
# [445]	validation-rmse:6.35121
# [446]	validation-rmse:6.35115
# [447]	validation-rmse:6.35086
# [448]	validation-rmse:6.35072
# [449]	validation-rmse:6.35042
# [450]	validation-rmse:6.35030
# [451]	validation-rmse:6.35006
# [452]	validation-rmse:6.34996
# [453]	validation-rmse:6.34996
# [454]	validation-rmse:6.34986
# [455]	validation-rmse:6.34967
# [456]	validation-rmse:6.34934
# [457]	validation-rmse:6.34935
# [458]	validation-rmse:6.34906
# [459]	validation-rmse:6.34897
# [460]	validation-rmse:6.34892
# [461]	validation-rmse:6.34878
# [462]	validation-rmse:6.34862
# [463]	validation-rmse:6.34847
# [464]	validation-rmse:6.34846
# [465]	validation-rmse:6.34841
# [466]	validation-rmse:6.34799
# [467]	validation-rmse:6.34791
# [468]	validation-rmse:6.34788
# [469]	validation-rmse:6.34763
# [470]	validation-rmse:6.34731
# [471]	validation-rmse:6.34692
# [472]	validation-rmse:6.34673
# [473]	validation-rmse:6.34659
# [474]	validation-rmse:6.34654
# [475]	validation-rmse:6.34639
# [476]	validation-rmse:6.34616
# [477]	validation-rmse:6.34596
# [478]	validation-rmse:6.34582
# [479]	validation-rmse:6.34568
# [480]	validation-rmse:6.34556
# [481]	validation-rmse:6.34549
# [482]	validation-rmse:6.34543
# [483]	validation-rmse:6.34524
# [484]	validation-rmse:6.34518
# [485]	validation-rmse:6.34504
# [486]	validation-rmse:6.34473
# [487]	validation-rmse:6.34470
# [488]	validation-rmse:6.34469
# [489]	validation-rmse:6.34448
# [490]	validation-rmse:6.34428
# [491]	validation-rmse:6.34426
# [492]	validation-rmse:6.34422
# [493]	validation-rmse:6.34407
# [494]	validation-rmse:6.34388
# [495]	validation-rmse:6.34357
# [496]	validation-rmse:6.34345
# [497]	validation-rmse:6.34356
# [498]	validation-rmse:6.34342
# [499]	validation-rmse:6.34336
# [500]	validation-rmse:6.34316
# [501]	validation-rmse:6.34320
# [502]	validation-rmse:6.34300
# [503]	validation-rmse:6.34287
# [504]	validation-rmse:6.34258
# [505]	validation-rmse:6.34260
# [506]	validation-rmse:6.34262
# [507]	validation-rmse:6.34243
# [508]	validation-rmse:6.34242
# [509]	validation-rmse:6.34230
# [510]	validation-rmse:6.34190
# [511]	validation-rmse:6.34181
# [512]	validation-rmse:6.34177
# [513]	validation-rmse:6.34168
# [514]	validation-rmse:6.34154
# [515]	validation-rmse:6.34130
# [516]	validation-rmse:6.34123
# [517]	validation-rmse:6.34110
# [518]	validation-rmse:6.34093
# [519]	validation-rmse:6.34079
# [520]	validation-rmse:6.34052
# [521]	validation-rmse:6.34045
# [522]	validation-rmse:6.34033
# [523]	validation-rmse:6.34003
# [524]	validation-rmse:6.33996
# [525]	validation-rmse:6.33977
# [526]	validation-rmse:6.33969
# [527]	validation-rmse:6.33948
# [528]	validation-rmse:6.33932
# [529]	validation-rmse:6.33913
# [530]	validation-rmse:6.33890
# [531]	validation-rmse:6.33879
# [532]	validation-rmse:6.33869
# [533]	validation-rmse:6.33859
# [534]	validation-rmse:6.33841
# [535]	validation-rmse:6.33821
# [536]	validation-rmse:6.33825
# [537]	validation-rmse:6.33813
# [538]	validation-rmse:6.33807
# [539]	validation-rmse:6.33786
# [540]	validation-rmse:6.33770
# [541]	validation-rmse:6.33759
# [542]	validation-rmse:6.33734
# [543]	validation-rmse:6.33722
# [544]	validation-rmse:6.33705
# [545]	validation-rmse:6.33693
# [546]	validation-rmse:6.33692
# [547]	validation-rmse:6.33673
# [548]	validation-rmse:6.33664
# [549]	validation-rmse:6.33674
# [550]	validation-rmse:6.33657
# [551]	validation-rmse:6.33638
# [552]	validation-rmse:6.33626
# [553]	validation-rmse:6.33601
# [554]	validation-rmse:6.33603
# [555]	validation-rmse:6.33590
# [556]	validation-rmse:6.33570
# [557]	validation-rmse:6.33575
# [558]	validation-rmse:6.33562
# [559]	validation-rmse:6.33544
# [560]	validation-rmse:6.33541
# [561]	validation-rmse:6.33536
# [562]	validation-rmse:6.33521
# [563]	validation-rmse:6.33495
# [564]	validation-rmse:6.33483
# [565]	validation-rmse:6.33465
# [566]	validation-rmse:6.33451
# [567]	validation-rmse:6.33442
# [568]	validation-rmse:6.33436
# [569]	validation-rmse:6.33431
# [570]	validation-rmse:6.33419
# [571]	validation-rmse:6.33422
# [572]	validation-rmse:6.33411
# [573]	validation-rmse:6.33407
# [574]	validation-rmse:6.33394
# [575]	validation-rmse:6.33374
# [576]	validation-rmse:6.33359
# [577]	validation-rmse:6.33329
# [578]	validation-rmse:6.33320
# [579]	validation-rmse:6.33304
# [580]	validation-rmse:6.33287
# [581]	validation-rmse:6.33280
# [582]	validation-rmse:6.33240
# [583]	validation-rmse:6.33242
# [584]	validation-rmse:6.33235
# [585]	validation-rmse:6.33232
# [586]	validation-rmse:6.33220
# [587]	validation-rmse:6.33202
# [588]	validation-rmse:6.33192
# [589]	validation-rmse:6.33183
# [590]	validation-rmse:6.33166
# [591]	validation-rmse:6.33174
# [592]	validation-rmse:6.33153
# [593]	validation-rmse:6.33160
# [594]	validation-rmse:6.33148
# [595]	validation-rmse:6.33147
# [596]	validation-rmse:6.33145
# [597]	validation-rmse:6.33132
# [598]	validation-rmse:6.33128
# [599]	validation-rmse:6.33104
# [600]	validation-rmse:6.33115
# [601]	validation-rmse:6.33122
# [602]	validation-rmse:6.33117
# [603]	validation-rmse:6.33105
# [604]	validation-rmse:6.33100
# [605]	validation-rmse:6.33093
# [606]	validation-rmse:6.33082
# [607]	validation-rmse:6.33082
# [608]	validation-rmse:6.33075
# [609]	validation-rmse:6.33068
# [610]	validation-rmse:6.33057
# [611]	validation-rmse:6.33038
# [612]	validation-rmse:6.33029
# [613]	validation-rmse:6.33012
# [614]	validation-rmse:6.33011
# [615]	validation-rmse:6.33001
# [616]	validation-rmse:6.32986
# [617]	validation-rmse:6.32976
# [618]	validation-rmse:6.32965
# [619]	validation-rmse:6.32965
# [620]	validation-rmse:6.32952
# [621]	validation-rmse:6.32943
# [622]	validation-rmse:6.32932
# [623]	validation-rmse:6.32923
# [624]	validation-rmse:6.32889
# [625]	validation-rmse:6.32852
# [626]	validation-rmse:6.32858
# [627]	validation-rmse:6.32849
# [628]	validation-rmse:6.32841
# [629]	validation-rmse:6.32825
# [630]	validation-rmse:6.32818
# [631]	validation-rmse:6.32808
# [632]	validation-rmse:6.32809
# [633]	validation-rmse:6.32790
# [634]	validation-rmse:6.32790
# [635]	validation-rmse:6.32781
# [636]	validation-rmse:6.32755
# [637]	validation-rmse:6.32747
# [638]	validation-rmse:6.32735
# [639]	validation-rmse:6.32734
# [640]	validation-rmse:6.32711
# [641]	validation-rmse:6.32696
# [642]	validation-rmse:6.32686
# [643]	validation-rmse:6.32669
# [644]	validation-rmse:6.32664
# [645]	validation-rmse:6.32643
# [646]	validation-rmse:6.32617
# [647]	validation-rmse:6.32625
# [648]	validation-rmse:6.32621
# [649]	validation-rmse:6.32601
# [650]	validation-rmse:6.32597
# [651]	validation-rmse:6.32586
# [652]	validation-rmse:6.32578
# [653]	validation-rmse:6.32561
# [654]	validation-rmse:6.32554
# [655]	validation-rmse:6.32555
# [656]	validation-rmse:6.32537
# [657]	validation-rmse:6.32519
# [658]	validation-rmse:6.32508
# [659]	validation-rmse:6.32485
# [660]	validation-rmse:6.32487
# [661]	validation-rmse:6.32478
# [662]	validation-rmse:6.32463
# [663]	validation-rmse:6.32450
# [664]	validation-rmse:6.32440
# [665]	validation-rmse:6.32436
# [666]	validation-rmse:6.32442
# [667]	validation-rmse:6.32440
# [668]	validation-rmse:6.32441
# [669]	validation-rmse:6.32445
# [670]	validation-rmse:6.32435
# [671]	validation-rmse:6.32415
# [672]	validation-rmse:6.32404
# [673]	validation-rmse:6.32392
# [674]	validation-rmse:6.32374
# [675]	validation-rmse:6.32347
# [676]	validation-rmse:6.32340
# [677]	validation-rmse:6.32345
# [678]	validation-rmse:6.32335
# [679]	validation-rmse:6.32325
# [680]	validation-rmse:6.32319
# [681]	validation-rmse:6.32324
# [682]	validation-rmse:6.32306
# [683]	validation-rmse:6.32291
# [684]	validation-rmse:6.32293
# [685]	validation-rmse:6.32272
# [686]	validation-rmse:6.32264
# [687]	validation-rmse:6.32265
# [688]	validation-rmse:6.32257
# [689]	validation-rmse:6.32253
# [690]	validation-rmse:6.32241
# [691]	validation-rmse:6.32228
# [692]	validation-rmse:6.32210
# [693]	validation-rmse:6.32193
# [694]	validation-rmse:6.32184
# [695]	validation-rmse:6.32176
# [696]	validation-rmse:6.32156
# [697]	validation-rmse:6.32147
# [698]	validation-rmse:6.32141
# [699]	validation-rmse:6.32134
# [700]	validation-rmse:6.32123
# [701]	validation-rmse:6.32116
# [702]	validation-rmse:6.32102
# [703]	validation-rmse:6.32092
# [704]	validation-rmse:6.32076
# [705]	validation-rmse:6.32057
# [706]	validation-rmse:6.32052
# [707]	validation-rmse:6.32055
# [708]	validation-rmse:6.32041
# [709]	validation-rmse:6.32037
# [710]	validation-rmse:6.32036
# [711]	validation-rmse:6.32014
# [712]	validation-rmse:6.32004
# [713]	validation-rmse:6.31986
# [714]	validation-rmse:6.31975
# [715]	validation-rmse:6.31961
# [716]	validation-rmse:6.31958
# [717]	validation-rmse:6.31963
# [718]	validation-rmse:6.31961
# [719]	validation-rmse:6.31968
# [720]	validation-rmse:6.31959
# [721]	validation-rmse:6.31950
# [722]	validation-rmse:6.31917
# [723]	validation-rmse:6.31914
# [724]	validation-rmse:6.31899
# [725]	validation-rmse:6.31907
# [726]	validation-rmse:6.31905
# [727]	validation-rmse:6.31910
# [728]	validation-rmse:6.31889
# [729]	validation-rmse:6.31873
# [730]	validation-rmse:6.31869
# [731]	validation-rmse:6.31879
# [732]	validation-rmse:6.31864
# [733]	validation-rmse:6.31856
# [734]	validation-rmse:6.31850
# [735]	validation-rmse:6.31831
# [736]	validation-rmse:6.31820
# [737]	validation-rmse:6.31809
# [738]	validation-rmse:6.31802
# [739]	validation-rmse:6.31767
# [740]	validation-rmse:6.31761
# [741]	validation-rmse:6.31756
# [742]	validation-rmse:6.31765
# [743]	validation-rmse:6.31757
# [744]	validation-rmse:6.31749
# [745]	validation-rmse:6.31734
# [746]	validation-rmse:6.31727
# [747]	validation-rmse:6.31730
# [748]	validation-rmse:6.31729
# [749]	validation-rmse:6.31717
# [750]	validation-rmse:6.31705
# [751]	validation-rmse:6.31687
# [752]	validation-rmse:6.31680
# [753]	validation-rmse:6.31671
# [754]	validation-rmse:6.31651
# [755]	validation-rmse:6.31636
# [756]	validation-rmse:6.31626
# [757]	validation-rmse:6.31622
# [758]	validation-rmse:6.31613
# [759]	validation-rmse:6.31598
# [760]	validation-rmse:6.31588
# [761]	validation-rmse:6.31584
# [762]	validation-rmse:6.31571
# [763]	validation-rmse:6.31568
# [764]	validation-rmse:6.31559
# [765]	validation-rmse:6.31561
# [766]	validation-rmse:6.31549
# [767]	validation-rmse:6.31548
# [768]	validation-rmse:6.31542
# [769]	validation-rmse:6.31545
# [770]	validation-rmse:6.31545
# [771]	validation-rmse:6.31538
# [772]	validation-rmse:6.31526
# [773]	validation-rmse:6.31489
# [774]	validation-rmse:6.31492
# [775]	validation-rmse:6.31485
# [776]	validation-rmse:6.31481
# [777]	validation-rmse:6.31464
# [778]	validation-rmse:6.31479
# [779]	validation-rmse:6.31461
# [780]	validation-rmse:6.31455
# [781]	validation-rmse:6.31459
# [782]	validation-rmse:6.31467
# [783]	validation-rmse:6.31465
# [784]	validation-rmse:6.31469
# [785]	validation-rmse:6.31456
# [786]	validation-rmse:6.31451
# [787]	validation-rmse:6.31437
# [788]	validation-rmse:6.31420
# [789]	validation-rmse:6.31386
# [790]	validation-rmse:6.31372
# [791]	validation-rmse:6.31372
# [792]	validation-rmse:6.31365
# [793]	validation-rmse:6.31352
# [794]	validation-rmse:6.31354
# [795]	validation-rmse:6.31342
# [796]	validation-rmse:6.31336
# [797]	validation-rmse:6.31321
# [798]	validation-rmse:6.31311
# [799]	validation-rmse:6.31302
# [800]	validation-rmse:6.31293
# [801]	validation-rmse:6.31299
# [802]	validation-rmse:6.31303
# [803]	validation-rmse:6.31297
# [804]	validation-rmse:6.31294
# [805]	validation-rmse:6.31288
# [806]	validation-rmse:6.31261
# [807]	validation-rmse:6.31263
# [808]	validation-rmse:6.31253
# [809]	validation-rmse:6.31250
# [810]	validation-rmse:6.31244
# [811]	validation-rmse:6.31243
# [812]	validation-rmse:6.31237
# [813]	validation-rmse:6.31236
# [814]	validation-rmse:6.31236
# [815]	validation-rmse:6.31228
# [816]	validation-rmse:6.31221
# [817]	validation-rmse:6.31220
# [818]	validation-rmse:6.31219
# [819]	validation-rmse:6.31204
# [820]	validation-rmse:6.31206
# [821]	validation-rmse:6.31206
# [822]	validation-rmse:6.31200
# [823]	validation-rmse:6.31205
# [824]	validation-rmse:6.31194
# [825]	validation-rmse:6.31188
# [826]	validation-rmse:6.31180
# [827]	validation-rmse:6.31174
# [828]	validation-rmse:6.31150
# [829]	validation-rmse:6.31147
# [830]	validation-rmse:6.31113
# [831]	validation-rmse:6.31115
# [832]	validation-rmse:6.31116
# [833]	validation-rmse:6.31122
# [834]	validation-rmse:6.31111
# [835]	validation-rmse:6.31107
# [836]	validation-rmse:6.31105
# [837]	validation-rmse:6.31100
# [838]	validation-rmse:6.31083
# [839]	validation-rmse:6.31074
# [840]	validation-rmse:6.31056
# [841]	validation-rmse:6.31045
# [842]	validation-rmse:6.31045
# [843]	validation-rmse:6.31039
# [844]	validation-rmse:6.31026
# [845]	validation-rmse:6.31024
# [846]	validation-rmse:6.31018
# [847]	validation-rmse:6.31003
# [848]	validation-rmse:6.30992
# [849]	validation-rmse:6.30993
# [850]	validation-rmse:6.30999
# [851]	validation-rmse:6.30970
# [852]	validation-rmse:6.30967
# [853]	validation-rmse:6.30965
# [854]	validation-rmse:6.30968
# [855]	validation-rmse:6.30956
# [856]	validation-rmse:6.30950
# [857]	validation-rmse:6.30945
# [858]	validation-rmse:6.30921
# [859]	validation-rmse:6.30899
# [860]	validation-rmse:6.30896
# [861]	validation-rmse:6.30851
# [862]	validation-rmse:6.30869
# [863]	validation-rmse:6.30865
# [864]	validation-rmse:6.30872
# [865]	validation-rmse:6.30859
# [866]	validation-rmse:6.30844
# [867]	validation-rmse:6.30827
# [868]	validation-rmse:6.30827
# [869]	validation-rmse:6.30818
# [870]	validation-rmse:6.30809
# [871]	validation-rmse:6.30807
# [872]	validation-rmse:6.30811
# [873]	validation-rmse:6.30817
# [874]	validation-rmse:6.30814
# [875]	validation-rmse:6.30798
# [876]	validation-rmse:6.30792
# [877]	validation-rmse:6.30785
# [878]	validation-rmse:6.30773
# [879]	validation-rmse:6.30784
# [880]	validation-rmse:6.30790
# [881]	validation-rmse:6.30789
# [882]	validation-rmse:6.30778
# [883]	validation-rmse:6.30789
# [884]	validation-rmse:6.30779
# [885]	validation-rmse:6.30777
# [886]	validation-rmse:6.30772
# [887]	validation-rmse:6.30758
# [888]	validation-rmse:6.30754
# [889]	validation-rmse:6.30737
# [890]	validation-rmse:6.30741
# [891]	validation-rmse:6.30745
# [892]	validation-rmse:6.30749
# [893]	validation-rmse:6.30769
# [894]	validation-rmse:6.30777
# [895]	validation-rmse:6.30777
# [896]	validation-rmse:6.30762
# [897]	validation-rmse:6.30752
# [898]	validation-rmse:6.30746
# [899]	validation-rmse:6.30749
# [900]	validation-rmse:6.30745
# [901]	validation-rmse:6.30734
# [902]	validation-rmse:6.30720
# [903]	validation-rmse:6.30716
# [904]	validation-rmse:6.30706
# [905]	validation-rmse:6.30705
# [906]	validation-rmse:6.30700
# [907]	validation-rmse:6.30686
# [908]	validation-rmse:6.30688
# [909]	validation-rmse:6.30670
# [910]	validation-rmse:6.30666
# [911]	validation-rmse:6.30645
# [912]	validation-rmse:6.30651
# [913]	validation-rmse:6.30654
# [914]	validation-rmse:6.30660
# [915]	validation-rmse:6.30648
# [916]	validation-rmse:6.30646
# [917]	validation-rmse:6.30640
# [918]	validation-rmse:6.30632
# [919]	validation-rmse:6.30632
# [920]	validation-rmse:6.30630
# [921]	validation-rmse:6.30620
# [922]	validation-rmse:6.30584
# [923]	validation-rmse:6.30592
# [924]	validation-rmse:6.30593
# [925]	validation-rmse:6.30597
# [926]	validation-rmse:6.30587
# [927]	validation-rmse:6.30579
# [928]	validation-rmse:6.30576
# [929]	validation-rmse:6.30570
# [930]	validation-rmse:6.30565
# [931]	validation-rmse:6.30562
# [932]	validation-rmse:6.30551
# [933]	validation-rmse:6.30539
# [934]	validation-rmse:6.30542
# [935]	validation-rmse:6.30543
# [936]	validation-rmse:6.30547
# [937]	validation-rmse:6.30549
# [938]	validation-rmse:6.30548
# [939]	validation-rmse:6.30548
# [940]	validation-rmse:6.30536
# [941]	validation-rmse:6.30525
# [942]	validation-rmse:6.30521
# [943]	validation-rmse:6.30512
# [944]	validation-rmse:6.30521
# [945]	validation-rmse:6.30523
# [946]	validation-rmse:6.30517
# [947]	validation-rmse:6.30511
# [948]	validation-rmse:6.30510
# [949]	validation-rmse:6.30512
# [950]	validation-rmse:6.30509
# [951]	validation-rmse:6.30506
# [952]	validation-rmse:6.30489
# [953]	validation-rmse:6.30465
# [954]	validation-rmse:6.30443
# [955]	validation-rmse:6.30442
# [956]	validation-rmse:6.30449
# [957]	validation-rmse:6.30447
# [958]	validation-rmse:6.30450
# [959]	validation-rmse:6.30443
# [960]	validation-rmse:6.30436
# [961]	validation-rmse:6.30432
# [962]	validation-rmse:6.30435
# [963]	validation-rmse:6.30428
# [964]	validation-rmse:6.30422
# [965]	validation-rmse:6.30423
# [966]	validation-rmse:6.30420
# [967]	validation-rmse:6.30423
# [968]	validation-rmse:6.30425
# [969]	validation-rmse:6.30427
# [970]	validation-rmse:6.30418
# [971]	validation-rmse:6.30425
# [972]	validation-rmse:6.30403
# [973]	validation-rmse:6.30398
# [974]	validation-rmse:6.30395
# [975]	validation-rmse:6.30398
# [976]	validation-rmse:6.30405
# [977]	validation-rmse:6.30393
# [978]	validation-rmse:6.30390
# [979]	validation-rmse:6.30365
# [980]	validation-rmse:6.30378
# [981]	validation-rmse:6.30369
# [982]	validation-rmse:6.30358
# [983]	validation-rmse:6.30352
# [984]	validation-rmse:6.30356
# [985]	validation-rmse:6.30358
# [986]	validation-rmse:6.30348
# [987]	validation-rmse:6.30374
# [988]	validation-rmse:6.30333
# [989]	validation-rmse:6.30327
# [990]	validation-rmse:6.30324
# [991]	validation-rmse:6.30323
# [992]	validation-rmse:6.30314
# [993]	validation-rmse:6.30309
# [994]	validation-rmse:6.30303
# [995]	validation-rmse:6.30293
# [996]	validation-rmse:6.30280
# [997]	validation-rmse:6.30273
# [998]	validation-rmse:6.30259
# [999]	validation-rmse:6.30243

# %%
logged_model = 'runs:/a86f0e4e71d947a7bc92e28bc77c48e4/models_mlflow'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)
loaded_model
# Out:
# 2023/05/28 14:45:21 WARNING mlflow.pyfunc: Detected one or more mismatches between the model's dependencies and the current Python environment:
#  - mlflow (current: 2.3.2, required: mlflow==2.3)
# To fix the mismatches, call `mlflow.pyfunc.get_model_dependencies(model_uri)` to fetch the model's environment and install dependencies using the resulting environment file.
# [14:45:21] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# mlflow.pyfunc.loaded_model:
#   artifact_path: models_mlflow
#   flavor: mlflow.xgboost
#   run_id: a86f0e4e71d947a7bc92e28bc77c48e4

# %%
xgboost_model = mlflow.xgboost.load_model(model_uri = logged_model)
xgboost_model
# Out:
# [14:48:00] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.

# %%
y_pred = xgboost_model.predict(valid)
y_pred[0:10]
# Out:
# array([14.954351,  7.142652, 14.259109, 24.31261 ,  9.302941, 17.112087,
#        11.339904,  8.502365,  8.948904, 20.343412], dtype=float32)

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():

        mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
        mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

# %%
from mlflow.tracking import MlflowClient

MLFLOW_TRACKING_URI = "sqlite:///mlflow.db"

client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)

# %%
#client.create_experiment(name = "my-cool-experiment")
from mlflow.entities import ViewType
runs = client.search_runs(
    experiment_ids=1,
    filter_string="",
    run_view_type=ViewType.ACTIVE_ONLY,
    max_results=5,
    order_by=["metrics.rmse ASC"]

)
for run in runs:
    print(f"run id : {run.info.run_id}, rmse: {run.data.metrics['rmse']:.4f}")
# Out:
# run id : ff25f5fccb5f4417bbdad6ba5a103901, rmse: 6.2873
# run id : a86f0e4e71d947a7bc92e28bc77c48e4, rmse: 6.3024
# run id : d8999453ae9f49a090d7f6c565ca2165, rmse: 6.3024
# run id : ad8d97a61bd347dca096d7a35c1b78f9, rmse: 6.3285
# run id : 30e635ed6f2847aba965adc190515568, rmse: 6.3484

# %%
import mlflow 

mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# %%
run_id = "ff25f5fccb5f4417bbdad6ba5a103901"
model_uri = f"runs:/{run_id}/model"
mlflow.register_model(model_uri = model_uri, name = "nyc-taxi-regressor")
# Out:
# Registered model 'nyc-taxi-regressor' already exists. Creating a new version of this model...
# 2023/05/28 15:58:11 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation. Model name: nyc-taxi-regressor, version 3
# Created version '3' of model 'nyc-taxi-regressor'.
# <ModelVersion: aliases=[], creation_timestamp=1685307491577, current_stage='None', description=None, last_updated_timestamp=1685307491577, name='nyc-taxi-regressor', run_id='ff25f5fccb5f4417bbdad6ba5a103901', run_link=None, source='/home/mlops/mlops-zoomcamp/02-experiment-tracking/mlruns/1/ff25f5fccb5f4417bbdad6ba5a103901/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=3>

# %%
model_name = "nyc-taxi-regressor"

latest_versions = client.get_latest_versions(name = model_name)
for version in latest_versions:
    print(f"version: {version.version}, stage:{version.current_stage}")
# Out:
# version: 3, stage:Staging

# %%
client.transition_model_version_stage(
    name=model_name,
    version=1,
    stage="staging",
    archive_existing_versions=False
)
# Out:
# <ModelVersion: aliases=[], creation_timestamp=1685306088962, current_stage='Staging', description='', last_updated_timestamp=1685308425326, name='nyc-taxi-regressor', run_id='a86f0e4e71d947a7bc92e28bc77c48e4', run_link='', source='/home/mlops/mlops-zoomcamp/02-experiment-tracking/mlruns/1/a86f0e4e71d947a7bc92e28bc77c48e4/artifacts/models_mlflow', status='READY', status_message=None, tags={'model': 'xgboost'}, user_id=None, version=1>

# %%
from sklearn.metrics import mean_squared_error
import pandas as pd


def read_dataframe(filename):
    df = pd.read_csv(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df


def preprocess(df, dv):
    df['PU_DO'] = df['PULocationID'] + '_' + df['DOLocationID']
    categorical = ['PU_DO']
    numerical = ['trip_distance']
    train_dicts = df[categorical + numerical].to_dict(orient='records')
    return dv.transform(train_dicts)


def test_model(name, stage, X_test, y_test):
    model = mlflow.pyfunc.load_model(f"models:/{name}/{stage}")
    y_pred = model.predict(X_test)
    return {"rmse": mean_squared_error(y_test, y_pred, squared=False)}

# %%
client.download_artifacts(run_id=run_id, path='preprocessor', dst_path='.')
# Out:
# /tmp/ipykernel_7764/2302784836.py:1: FutureWarning: ``mlflow.tracking.client.MlflowClient.download_artifacts`` is deprecated since 2.0. This method will be removed in a future release. Use ``mlflow.artifacts.download_artifacts`` instead.
#   client.download_artifacts(run_id=run_id, path='preprocessor', dst_path='.')
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 client.download_artifacts(run_id=run_id, path='preprocessor', dst_path='.')
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.10/site-packages/mlflow/utils/annotations.py:95, in deprecated.<locals>.deprecated_decorator.<locals>.deprecated_func(*args, **kwargs)
#      92 @wraps(func)
#      93 def deprecated_func(*args, **kwargs):
#      94     warnings.warn(notice, category=FutureWarning, stacklevel=2)
# ---> 95     return func(*args, **kwargs)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.10/site-packages/mlflow/tracking/client.py:1496, in MlflowClient.download_artifacts(self, run_id, path, dst_path)
#    1451 @deprecated("mlflow.artifacts.download_artifacts", "2.0")
#    1452 def download_artifacts(self, run_id: str, path: str, dst_path: Optional[str] = None) -> str:
#    1453     """
#    1454     Download an artifact file or directory from a run to a local directory if applicable,
#    1455     and return a local path for it.
#    (...)
#    1494         Artifacts: ['features.txt']
#    1495     """
# -> 1496     return self._tracking_client.download_artifacts(run_id, path, dst_path)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/client.py:475, in TrackingServiceClient.download_artifacts(self, run_id, path, dst_path)
#     461 def download_artifacts(self, run_id, path, dst_path=None):
#     462     """
#     463     Download an artifact file or directory from a run to a local directory if applicable,
#     464     and return a local path for it.
#    (...)
#     473     :return: Local path of desired artifact.
#     474     """
# --> 475     return self._get_artifact_repo(run_id).download_artifacts(path, dst_path)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.10/site-packages/mlflow/store/artifact/local_artifact_repo.py:74, in LocalArtifactRepository.download_artifacts(self, artifact_path, dst_path)
#      61 """
#      62 Artifacts tracked by ``LocalArtifactRepository`` already exist on the local filesystem.
#      63 If ``dst_path`` is ``None``, the absolute filesystem path of the specified artifact is
#    (...)
#      71 :return: Absolute path of the local filesystem location containing the desired artifacts.
#      72 """
#      73 if dst_path:
# ---> 74     return super().download_artifacts(artifact_path, dst_path)
#      75 # NOTE: The artifact_path is expected to be in posix format.
#      76 # Posix paths work fine on windows but just in case we normalize it here.
#      77 local_artifact_path = os.path.join(self.artifact_dir, os.path.normpath(artifact_path))
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.10/site-packages/mlflow/store/artifact/artifact_repo.py:268, in ArtifactRepository.download_artifacts(self, artifact_path, dst_path)
#     265         failed_downloads[inflight_download.src_artifact_path] = repr(e)
#     267 if len(failed_downloads) > 0:
# --> 268     raise MlflowException(
#     269         message=(
#     270             "The following failures occurred while downloading one or more"
#     271             " artifacts from {artifact_root}: {failures}".format(
#     272                 artifact_root=self.artifact_uri,
#     273                 failures=failed_downloads,
#     274             )
#     275         )
#     276     )
#     277 return dst_local_path
#
# MlflowException: The following failures occurred while downloading one or more artifacts from /home/mlops/mlops-zoomcamp/02-experiment-tracking/mlruns/1/ff25f5fccb5f4417bbdad6ba5a103901/artifacts: {'preprocessor': "FileNotFoundError(2, 'No such file or directory')"}
